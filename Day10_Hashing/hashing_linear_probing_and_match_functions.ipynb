# %% [markdown]
# <a href="https://colab.research.google.com/github/shehbaz010/DSA_Training/blob/main/Day10_Hashing/hashing_linear_probing_and_match_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Hashing

class HashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for _ in range(self.size)]

    def hash_function(self, key):
        return key % self.size

    def insert(self, key):
        index = self.hash_function(key)
        self.table[index].append(key)

    def display(self):
        print(self.table)

h = HashTable(10)
h.insert(15)
h.insert(25)
h.insert(35)
h.insert(45)
h.display()
# Out:
# [[], [], [], [], [], [15, 25, 35, 45], [], [], [], []]

# %%
# Linear probing

class LinearProbing:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_function(self, key):
        return key % self.size

    def insert(self, key):
        index = self.hash_function(key)

        while self.table[index] is not None:
            index = (index + 1) % self.size


        self.table[index] = key

    def display(self):
        print(self.table)

h = LinearProbing(10)
h.insert(15)
h.insert(25)
h.insert(35)
h.insert(45)
h.display()
# Out:
# [None, None, None, None, None, 15, 25, 35, 45, None]

# %%
# HashTable

class HashTable:
    def __init__(self, size):
        self.size = size
        self.table = [[] for i in range(self.size)]

    def hash_function(self, key):
        return key % self.size

    def insert(self, key, value):
        index = self.hash_function(key)
        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                self.table[index][i] = (key, value)
                return
        self.table[index].append((key, value))


    def search(self, key):
        index = self.hash_function(key)
        for k, v in self.table[index]:
            if k == key:
                return v
        return "Not found"


    def delete(self, key):
        index = self.hash_function(key)

        for i, (k, v) in enumerate(self.table[index]):
            if k == key:
                del self.table[index][i]
                return


    def display(self):
        print(self.table)

h = HashTable(10)
h.insert(1, "Ashish")
h.insert(25, "Bobu")
print(h.search(25))

h.display()
h.delete(1)
h.display()
# Out:
# Bobu
# [[], [(1, 'Ashish')], [], [], [], [(25, 'Bobu')], [], [], [], []]
# [[], [], [], [], [], [(25, 'Bobu')], [], [], [], []]

# %%
#Regular Expression program-1

import re
count = 0
pattern = re.compile("ab")
matcher = pattern.finditer("abaababab")

for match in matcher:
    count += 1
    print(match.start(), "...", match.end(), "...", match.group())
print("total no of group occurrences : ", count)
# Out:
# 0 ... 2 ... ab
# 3 ... 5 ... ab
# 5 ... 7 ... ab
# 7 ... 9 ... ab
# total no of group occurrences :  4

# %%
#Regular Expression program-2

import re
count = 0
# pattern = re.compile("ab")
# matcher = pattern.finditer("abaababab")

# print(matcher)
matcher=re.finditer("ab","abaababab")
for match in matcher:
    count += 1
    print(match.start(), "...", match.end(), "...", match.group())
print("total no of group occurrences : ", count)

# %%
#pattern

import re
x = "[abc]"
# x = "[^abc]"
# x = "[a-z]"
# x = "[0-9]"
# x = "[a-zA-Z0-9]"
# x = "[^a-zA-Z0-9]"
matcher = re.finditer(x, "a7b@20k2$D8z")
# print(matcher)
for match in matcher:
    print(match.start(), "...", match.group())
# Out:
# 0 ... a
# 2 ... b

# %%
# \w ==> Any word character [a-zA-Z0-9]
# \W ==> Any character except word character (Special Character)
# .   ==> Any character including special characters

import re

x = "\s"
x = "\S"
x = "\d"
x = "\D"
x = "\w"
x = "\W"
x = "."

matcher = re.finditer(x, "a7b D 2@k2D8z")

for match in matcher:
    print(match.start(), "...", match.group())
# Out:
# 0 ... a
# 1 ... 7
# 2 ... b
# 3 ...
# 4 ... D
# 5 ...
# 6 ... 2
# 7 ... @
# 8 ... k
# 9 ... 2
# 10 ... D
# 11 ... 8
# 12 ... z
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:11: SyntaxWarning: invalid escape sequence '\w'
# <>:12: SyntaxWarning: invalid escape sequence '\W'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\D'
# <>:11: SyntaxWarning: invalid escape sequence '\w'
# <>:12: SyntaxWarning: invalid escape sequence '\W'
# /tmp/ipykernel_6396/3380813709.py:7: SyntaxWarning: invalid escape sequence '\s'
#   x = "\s"
# /tmp/ipykernel_6396/3380813709.py:8: SyntaxWarning: invalid escape sequence '\S'
#   x = "\S"
# ...

# %%
#pattern

import re

x = "a"
x = "a+"
x = "a*"
x = "a?"
x = "a{3}"
x = "a{2, 3}"

matcher = re.finditer(x, "a7b@20k2$D8z")
print(matcher)
for match in matcher:
    print(match.start(), "...", match.group())

# %%
# Match function

import re

user_pattern = input("enter any regex pattern = ")
m = re.match(user_pattern, "abc@xyz_pqr*")
if m is not None:
  print("Matching is available at the beginning of the string")
  print("start index : ", m.start())
  print("end index : ", m.end())
else:
  print("Matching is not available at the beginning")
# Out:
# enter any regex pattern = eagfaavdbgx
# Matching is not available at the beginning

# %%
# FullMatch function

import re

user_pattern = input("enter any regex pattern = ")
m = re.fullmatch(user_pattern, "abc@xyz_pqr*")
if m is not None:
  print("Matching is available for the entire string")
  print("start index : ", m.start())
  print("end index : ", m.end())
else:
  print("No full match found")
# Out:
# enter any regex pattern = 12thsxxj
# No full match found

# %%
# findall function

import re
list = re.findall("[09]","ab4fahuiy38oyq43gl@53%$6")
print(list)
for i in list:
    print(i)
# Out:
# []

# %%
# Replacement

import re
result_string = re.sub("[a-z]", "abfa@4bc_v5&bz", "your target string here")
print(result_string)
print(type(result_string))
# Out:
# abfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bz abfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bz abfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bz abfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bzabfa@4bc_v5&bz
# <class 'str'>

# %%
# Check mobile no is valid or not using match function

import re

num = input("Enter no = ")
match = re.fullmatch("[6 - 9]\\d{9}", num)
if match != None:
  print("Valid Mobile Number")
else:
  print("Invalid Mobile Number")
# Out:
# Enter no = 6438975204
# Valid Mobile Number
